# %% [markdown]
# # ASSIGNMENT PART 1

# %% [markdown]
# #### Let's first obtain the data from Wikipedia page that is in the table of postal codes and transform it into a pandas dataframe. We will be using Pandas and BeautifulSoup libraries for webscraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))[0]
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### Data wrangling and cleaning up the above dataframe. Removing the Not assigned values

# %%
# Dropping the rows where 'Borough'=='Not assigned'
df.drop(df[df['Borough']=='Not assigned'].index, inplace = True)  
df.reset_index(drop=True, inplace=True)
# Replacing the NOt assigned values of Neighbourhood with that of corresponding Borough.
for index in df[df['Neighbourhood']=='Not assigned'].index:
    df['Neighbourhood'][index]=df['Borough'][index]
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M5A  Downtown Toronto
# 4        M6A        North York
# 5        M6A        North York
# 6        M7A      Queen's Park
# 7        M9A         Etobicoke
# 8        M1B       Scarborough
# 9        M1B       Scarborough
# 10       M3B        North York
# 11       M4B         East York
# 12       M4B         East York
# 13       M5B  Downtown Toronto
# 14       M5B  Downtown Toronto
# 15       M6B        North York
# 16       M9B         Etobicoke
# 17       M9B         Etobicoke
# 18       M9B         Etobicoke
# 19       M9B         Etobicoke
# 20       M9B         Etobicoke
# 21       M1C       Scarborough
# 22       M1C       Scarborough
# 23       M1C       Scarborough
# 24       M3C        North York
# 25       M3C        North York
# 26       M4C         East York
# 27       M5C  Downtown Toronto
# 28       M6C              York
# 29       M9C         Etobicoke
# ..       ...               ...
# 181      M9V         Etobicoke
# 182      M1W       Scarborough
# 183      M4W  Downtown Toronto
# 184      M5W  Downtown Toronto
# 185      M8W         Etobicoke
# 186      M8W         Etobicoke
# 187      M9W         Etobicoke
# 188      M1X       Scarborough
# 189      M4X  Downtown Toronto
# 190      M4X  Downtown Toronto
# 191      M5X  Downtown Toronto
# 192      M5X  Downtown Toronto
# 193      M8X         Etobicoke
# 194      M8X         Etobicoke
# 195      M8X         Etobicoke
# 196      M4Y  Downtown Toronto
# 197      M7Y      East Toronto
# 198      M8Y         Etobicoke
# 199      M8Y         Etobicoke
# 200      M8Y         Etobicoke
# 201      M8Y         Etobicoke
# 202      M8Y         Etobicoke
# 203      M8Y         Etobicoke
# 204      M8Y         Etobicoke
# 205      M8Y         Etobicoke
# 206      M8Z         Etobicoke
# 207      M8Z         Etobicoke
# 208      M8Z         Etobicoke
# 209      M8Z         Etobicoke
# 210      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Queen's Park
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
# Combining the Neighbourhoods with same Postcode(separated by comma).
df_toronto=pd.DataFrame(columns=['Postcode','Borough', 'Neighbourhood'])
df_toronto['Postcode'] = df.Postcode.unique()
Neighbourhood_list = []
for row in range(df_toronto.shape[0]):
    for i in range(df.shape[0]):
        if df['Postcode'][i]==df_toronto['Postcode'][row]:
            df_toronto['Borough'][row] = df['Borough'][i]
            Neighbourhood_list.append(df['Neighbourhood'][i])
    df_toronto['Neighbourhood'][row] = ', '.join(Neighbourhood_list)
    Neighbourhood_list = []
df_toronto
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Harbourfront, Regent Park
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Queen's Park
# 5                                     Islington Avenue
# 6                                       Rouge, Malvern
# 7                                      Don Mills North
# 8                      Woodbine Gardens, Parkview Hill
# 9                             Ryerson, Garden District
# 10                                           Glencairn
# 11   Cloverdale, Islington, Martin Grove, Princess ...
# 12              Highland Creek, Rouge Hill, Port Union
# 13                    Flemingdon Park, Don Mills South
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Downsview North, Wilson Heights
# 29                                    Thorncliffe Park
# ..                                                 ...
# 73                                  North Toronto West
# 74                 The Annex, North Midtown, Yorkville
# 75                              Parkdale, Roncesvalles
# 76               Canada Post Gateway Processing Centre
# 77   Kingsview Village, Martin Grove Gardens, Richv...
# 78                                           Agincourt
# 79                                          Davisville
# 80                      Harbord, University of Toronto
# 81                                  Runnymede, Swansea
# 82             Clarks Corners, Sullivan, Tam O'Shanter
# 83                         Moore Park, Summerhill East
# 84           Chinatown, Grange Park, Kensington Market
# 85   Agincourt North, L'Amoreaux East, Milliken, St...
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...
# 90                                     L'Amoreaux West
# 91                                            Rosedale
# 92                     Stn A PO Boxes 25 The Esplanade
# 93                              Alderwood, Long Branch
# 94                                           Northwest
# 95                                         Upper Rouge
# 96                         Cabbagetown, St. James Town
# 97              First Canadian Place, Underground city
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# 101  Humber Bay, King's Mill Park, Kingsway Park So...
# 102  Kingsway Park South West, Mimico NW, The Queen...
#
# [103 rows x 3 columns]

# %% [markdown]
# #### no of rows in the dataframe

# %%
df_toronto.shape
# Out:
# (103, 3)

# %% [markdown]
# # ASSIGNMENT PART 2

# %% [markdown]
# ####  LOADING THE COORDINATES PRESENT IN THE DATAFRAME

# %%
df_coordinates = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
df_coordinates.rename(columns={'Postal Code': 'Postcode'}, inplace=True)
# DISPLAY THE COORDINATES ON THE BASES OF LATITUDE AND LONGITUDE
df_coordinates.head()
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476

# %%
# MERGING THE ALL DATA TOGETHER

df_toronto = pd.merge(df_toronto,df_coordinates, on=['Postcode'])
# DISPLAY THE DATA FRAME TORONTO
df_toronto
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A      Queen's Park
# 5        M9A         Etobicoke
# 6        M1B       Scarborough
# 7        M3B        North York
# 8        M4B         East York
# 9        M5B  Downtown Toronto
# 10       M6B        North York
# 11       M9B         Etobicoke
# 12       M1C       Scarborough
# 13       M3C        North York
# 14       M4C         East York
# 15       M5C  Downtown Toronto
# 16       M6C              York
# 17       M9C         Etobicoke
# 18       M1E       Scarborough
# 19       M4E      East Toronto
# 20       M5E  Downtown Toronto
# 21       M6E              York
# 22       M1G       Scarborough
# 23       M4G         East York
# 24       M5G  Downtown Toronto
# 25       M6G  Downtown Toronto
# 26       M1H       Scarborough
# 27       M2H        North York
# 28       M3H        North York
# 29       M4H         East York
# ..       ...               ...
# 73       M4R   Central Toronto
# 74       M5R   Central Toronto
# 75       M6R      West Toronto
# 76       M7R       Mississauga
# 77       M9R         Etobicoke
# 78       M1S       Scarborough
# 79       M4S   Central Toronto
# 80       M5S  Downtown Toronto
# 81       M6S      West Toronto
# 82       M1T       Scarborough
# 83       M4T   Central Toronto
# 84       M5T  Downtown Toronto
# 85       M1V       Scarborough
# 86       M4V   Central Toronto
# 87       M5V  Downtown Toronto
# 88       M8V         Etobicoke
# 89       M9V         Etobicoke
# 90       M1W       Scarborough
# 91       M4W  Downtown Toronto
# 92       M5W  Downtown Toronto
# 93       M8W         Etobicoke
# 94       M9W         Etobicoke
# 95       M1X       Scarborough
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood  Latitude_x  \
# 0                                            Parkwoods   43.753259
# 1                                     Victoria Village   43.725882
# 2                            Harbourfront, Regent Park   43.654260
# 3                     Lawrence Heights, Lawrence Manor   43.718518
# 4                                         Queen's Park   43.662301
# 5                                     Islington Avenue   43.667856
# 6                                       Rouge, Malvern   43.806686
# 7                                      Don Mills North   43.745906
# 8                      Woodbine Gardens, Parkview Hill   43.706397
# 9                             Ryerson, Garden District   43.657162
# 10                                           Glencairn   43.709577
# 11   Cloverdale, Islington, Martin Grove, Princess ...   43.650943
# 12              Highland Creek, Rouge Hill, Port Union   43.784535
# 13                    Flemingdon Park, Don Mills South   43.725900
# 14                                    Woodbine Heights   43.695344
# 15                                      St. James Town   43.651494
# 16                                  Humewood-Cedarvale   43.693781
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...   43.643515
# 18                   Guildwood, Morningside, West Hill   43.763573
# 19                                         The Beaches   43.676357
# 20                                         Berczy Park   43.644771
# 21                                 Caledonia-Fairbanks   43.689026
# 22                                              Woburn   43.770992
# 23                                             Leaside   43.709060
# 24                                  Central Bay Street   43.657952
# 25                                            Christie   43.669542
# 26                                           Cedarbrae   43.773136
# 27                                   Hillcrest Village   43.803762
# 28     Bathurst Manor, Downsview North, Wilson Heights   43.754328
# 29                                    Thorncliffe Park   43.705369
# ..                                                 ...         ...
# 73                                  North Toronto West   43.715383
# 74                 The Annex, North Midtown, Yorkville   43.672710
# 75                              Parkdale, Roncesvalles   43.648960
# 76               Canada Post Gateway Processing Centre   43.636966
# 77   Kingsview Village, Martin Grove Gardens, Richv...   43.688905
# 78                                           Agincourt   43.794200
# 79                                          Davisville   43.704324
# 80                      Harbord, University of Toronto   43.662696
# 81                                  Runnymede, Swansea   43.651571
# 82             Clarks Corners, Sullivan, Tam O'Shanter   43.781638
# 83                         Moore Park, Summerhill East   43.689574
# 84           Chinatown, Grange Park, Kensington Market   43.653206
# 85   Agincourt North, L'Amoreaux East, Milliken, St...   43.815252
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi